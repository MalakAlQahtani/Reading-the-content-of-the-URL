# %%
from urllib.request import urlopen

html = urlopen("https://pnu.edu.sa").read().decode('utf-8')
print(html)
# Out:
# <!DOCTYPE html >
# <html dir="rtl" class="ms-isBot" lang="ar-SA">
#
#     <head><meta http-equiv="X-UA-Compatible" content="IE=10" /><meta name="Title" content="Microsoft&#32;SharePoint" /><meta name="GENERATOR" content="Microsoft&#32;SharePoint" /><meta http-equiv="Content-type" content="text/html;&#32;charset=utf-8" /><meta http-equiv="Expires" content="0" /><title>
#
# 	الصفحات - Home
#
# </title><link rel="stylesheet" type="text/css" href="/Style%20Library/ar-SA/Themable/Core%20Styles/pagelayouts15.css"/>
# <link rel="stylesheet" type="text/css" href="/_layouts/15/1025/styles/Themable/corev15.css?rev=kABoMYKCOpczdZrXK5psAg%3D%3DTAG0"/>
# <link rel="stylesheet" type="text/css" href="/_layouts/15/PNU_Theme/ar-SA/css/bootstrapARABIC.min.css"/>
# <link rel="stylesheet" type="text/css" href="/_layouts/15/PNU_Theme/ar-SA/css/bootstrap-gridARABIC.min.css"/>
# <link rel="stylesheet" type="text/css" href="/_layouts/15/PNU_Theme/ar-SA/css/pnu-defult.css"/>
# ...
